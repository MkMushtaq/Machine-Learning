# %%
import numpy as np
import pandas as pd

# %%
from sklearn.datasets import load_digits
data = load_digits()
dir(data)
# Out:
# ['DESCR', 'data', 'images', 'target', 'target_names']

# %%
x = data['data']
y = data['target']
y.shape
# Out:
# (1797,)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
model = GridSearchCV(SVC(gamma='auto'), {
    'C': [1,5,10,15],
    'kernel': ['rbf', 'linear']
})
model.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='auto', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': [1, 5, 10, 15], 'kernel': ['rbf', 'linear']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
model.score(x_test, y_test)
# Out:
# 0.975

# %%
df = pd.DataFrame(model.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
df.sort_values(by = ['rank_test_score'])
# Out:
#                           params  mean_test_score  rank_test_score
# 1   {'C': 1, 'kernel': 'linear'}         0.977033                1
# 3   {'C': 5, 'kernel': 'linear'}         0.977033                1
# 5  {'C': 10, 'kernel': 'linear'}         0.977033                1
# 7  {'C': 15, 'kernel': 'linear'}         0.977033                1
# 2      {'C': 5, 'kernel': 'rbf'}         0.439854                5
# 4     {'C': 10, 'kernel': 'rbf'}         0.439854                5
# 6     {'C': 15, 'kernel': 'rbf'}         0.439854                5
# 0      {'C': 1, 'kernel': 'rbf'}         0.386249                8
